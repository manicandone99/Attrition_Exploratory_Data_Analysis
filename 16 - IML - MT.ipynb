# %%
# Set the working directory
import os
os.chdir("C:\\Users\\benwi\\Downloads\\IML-SESSION-2")

#Read the attrition.csv data
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

atr = pd.read_csv("attrition.csv")

# %%
atr.describe()
# Out:
#                Age    Attrition  EnvironmentSatisfaction  JobInvolvement  \
# count  1470.000000  1470.000000              1470.000000     1470.000000
# mean     36.923810     0.161224                 2.721769        2.729932
# std       9.135373     0.367863                 1.093082        0.711561
# min      18.000000     0.000000                 1.000000        1.000000
# 25%      30.000000     0.000000                 2.000000        2.000000
# 50%      36.000000     0.000000                 3.000000        3.000000
# 75%      43.000000     0.000000                 4.000000        3.000000
# max      60.000000     1.000000                 4.000000        4.000000
#
#           JobLevel  JobSatisfaction  MonthlyIncome  TotalWorkingYears  \
# count  1470.000000      1470.000000    1470.000000        1470.000000
# mean      2.063946         2.728571    6502.931293          11.279592
# std       1.106940         1.102846    4707.956783           7.780782
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# ## AGE

# %%
dat=pd.crosstab(atr.Age,columns="frequency")
dat         # distribution of ages of all employees
            #analysis:out of all ,11 employees are from the age group of 20.
# Out:
# col_0  frequency
# Age
# 18             8
# 19             9
# 20            11
# 21            13
# 22            16
# 23            14
# 24            26
# 25            26
# 26            39
# 27            48
# 28            48
# 29            68
# 30            60
# 31            69
# 32            61
# 33            58
# 34            77
# 35            78
# 36            69
# 37            50
# 38            58
# 39            42
# 40            57
# 41            40
# 42            46
# 43            32
# 44            33
# 45            41
# 46            33
# 47            24
# 48            19
# 49            24
# 50            30
# 51            19
# 52            18
# 53            19
# 54            18
# 55            22
# 56            14
# 57             4
# 58            14
# 59            10
# 60             5

# %% [markdown]
# ## Visualization of  Age

# %%
atr["Age"].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
atr.hist(column="Age",grid=False,figsize=(5,4),color="orange",edgecolor="white",bins=20)
plt.ylabel("Number of employees",fontsize=10)
plt.show()

# %% [markdown]
# from the graph we can conclude that the age is slightly normally distributed

# %% [markdown]
# ## Business Travel

# %%
n=len(atr)

# %%
univ=pd.crosstab(atr.BusinessTravel,columns="frequency")
univ
# Out:
# col_0              frequency
# BusinessTravel
# Non-Travel               150
# Travel_Frequently        277
# Travel_Rarely           1043

# %% [markdown]
# ## Visualization of Business Travel

# %%
univ.plot(kind='bar')
plt.show()

# %% [markdown]
# ## EducationField

# %%
univ=pd.crosstab(atr.EducationField,columns="frequency")
univ
# Out:
# col_0             frequency
# EducationField
# Human Resources          27
# Life Sciences           606
# Marketing               159
# Medical                 464
# Other                    82
# Technical Degree        132

# %% [markdown]
# ## Visualization of Education field

# %%
univ.plot(kind='bar')
plt.show()

# %% [markdown]
# ## Gender

# %%
univ=pd.crosstab(atr.Gender,columns="frequency")
univ
# Out:
# col_0   frequency
# Gender
# Female        588
# Male          882

# %% [markdown]
# ## Visualisation of Gender

# %%
univ.plot(kind='bar')
plt.show()

# %% [markdown]
# ## JobInvolvement

# %%
univ=pd.crosstab(atr.JobInvolvement,columns="frequency")
univ
# Out:
# col_0           frequency
# JobInvolvement
# 1                      83
# 2                     375
# 3                     868
# 4                     144

# %% [markdown]
# ## Visualization of JobInvolvement

# %%
univ.plot(kind='bar')
plt.show()

# %% [markdown]
# ## JobSatisfaction

# %%
univ=pd.crosstab(atr.JobSatisfaction,columns="frequency")
univ
# Out:
# col_0            frequency
# JobSatisfaction
# 1                      289
# 2                      280
# 3                      442
# 4                      459

# %% [markdown]
# ## Visualization of Job satisfaction

# %%
univ.plot(kind='bar')
plt.show()

# %% [markdown]
# ## MaritalStatus

# %%
univ=pd.crosstab(atr.MaritalStatus,columns="frequency")
univ
# Out:
# col_0          frequency
# MaritalStatus
# Divorced             327
# Married              673
# Single               470

# %% [markdown]
# ## Visualization of Marital status

# %%
univ.plot(kind='bar')
plt.show()

# %% [markdown]
# ## MonthlyIncome

# %%
univ=pd.crosstab(atr.MonthlyIncome,columns="frequency")/n*100
univ
# Out:
# col_0          frequency
# MonthlyIncome
# 1009            0.068027
# 1051            0.068027
# 1052            0.068027
# 1081            0.068027
# 1091            0.068027
# ...                  ...
# 19859           0.068027
# 19926           0.068027
# 19943           0.068027
# 19973           0.068027
# 19999           0.068027
#
# [1349 rows x 1 columns]

# %% [markdown]
# ## Visualization of Monthly income

# %%
atr["MonthlyIncome"].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
## This graph shows that the distribution is left skewed, hence we can say that most of the employees in the company 
## are getting paid less than 6000

# %% [markdown]
# ## OverTime

# %%
univ=pd.crosstab(atr.OverTime,columns="frequency")
univ
# Out:
# col_0     frequency
# OverTime
# No             1054
# Yes             416

# %% [markdown]
# ## Visualization of OverTime

# %%
univ.plot(kind='bar')
plt.show()

# %% [markdown]
# ## TotalWorkingYears

# %%
univ=pd.crosstab(atr.TotalWorkingYears,columns="frequency")
univ
# Out:
# col_0              frequency
# TotalWorkingYears
# 0                         11
# 1                         81
# 2                         31
# 3                         42
# 4                         63
# 5                         88
# 6                        125
# 7                         81
# 8                        103
# 9                         96
# 10                       202
# 11                        36
# 12                        48
# 13                        36
# 14                        31
# 15                        40
# 16                        37
# 17                        33
# 18                        27
# 19                        22
# 20                        30
# 21                        34
# 22                        21
# 23                        22
# 24                        18
# 25                        14
# 26                        14
# 27                         7
# 28                        14
# 29                        10
# ...

# %% [markdown]
#  ##  Visualization of TotalWorkingYears

# %%
atr.hist(column = 'TotalWorkingYears')
plt.show()

# %%
### This graph shows that the distribution is left skewed, hence we can say that most of the employees in the company 
## are having work experience in the range of 4-13

# %% [markdown]
# ## WorkLifeBalance

# %%
univ=pd.crosstab(atr.WorkLifeBalance,columns="frequency")
univ
# Out:
# col_0            frequency
# WorkLifeBalance
# 1                       80
# 2                      344
# 3                      893
# 4                      153

# %% [markdown]
# ## Visualization of  Worklife balance

# %%
univ.plot(kind='barh',color='red')
plt.show()

# %% [markdown]
# ## YearsAtCompany

# %%
univ=pd.crosstab(atr.YearsAtCompany,columns="frequency")/n*100
univ
# Out:
# col_0           frequency
# YearsAtCompany
# 0                2.993197
# 1               11.632653
# 2                8.639456
# 3                8.707483
# 4                7.482993
# 5               13.333333
# 6                5.170068
# 7                6.122449
# 8                5.442177
# 9                5.578231
# 10               8.163265
# 11               2.176871
# 12               0.952381
# 13               1.632653
# 14               1.224490
# 15               1.360544
# 16               0.816327
# 17               0.612245
# 18               0.884354
# 19               0.748299
# 20               1.836735
# 21               0.952381
# 22               1.020408
# 23               0.136054
# 24               0.408163
# 25               0.272109
# 26               0.272109
# 27               0.136054
# 29               0.136054
# 30               0.068027
# 31               0.204082
# 32               0.204082
# 33               0.340136
# 34               0.068027
# ...

# %% [markdown]
# ## Visualization of Years at Company

# %%
atr.hist(column = 'YearsAtCompany')
plt.show()

# %%
## This graph shows that the distribution is left skewed, hence we can say that most of the employees stayed in the company 
## are in the range of 0-8

# %% [markdown]
# ## YearsInCurrentRole

# %%
univ=pd.crosstab(atr.YearsInCurrentRole,columns="frequency")/n*100
univ
# Out:
# col_0               frequency
# YearsInCurrentRole
# 0                   16.598639
# 1                    3.877551
# 2                   25.306122
# 3                    9.183673
# 4                    7.074830
# 5                    2.448980
# 6                    2.517007
# 7                   15.102041
# 8                    6.054422
# 9                    4.557823
# 10                   1.972789
# 11                   1.496599
# 12                   0.680272
# 13                   0.952381
# 14                   0.748299
# 15                   0.544218
# 16                   0.476190
# 17                   0.272109
# 18                   0.136054

# %% [markdown]
# ## Visualization of YearsInCurrentRole

# %%
atr.hist(column = 'YearsInCurrentRole')
plt.show()

# %% [markdown]
# ## YearsSinceLastPromotion

# %%
univ=pd.crosstab(atr.YearsSinceLastPromotion,columns="frequency")/n*100
univ
# Out:
# col_0                    frequency
# YearsSinceLastPromotion
# 0                        39.523810
# 1                        24.285714
# 2                        10.816327
# 3                         3.537415
# 4                         4.149660
# 5                         3.061224
# 6                         2.176871
# 7                         5.170068
# 8                         1.224490
# 9                         1.156463
# 10                        0.408163
# 11                        1.632653
# 12                        0.680272
# 13                        0.680272
# 14                        0.612245
# 15                        0.884354

# %% [markdown]
# ## Visualisation of Years since last promotion

# %%
atr.hist(column = 'YearsSinceLastPromotion')
plt.show()

# %% [markdown]
# ## YearsWithCurrManager

# %%
univ=pd.crosstab(atr.YearsWithCurrManager,columns="frequency")/n*100
univ
# Out:
# col_0                 frequency
# YearsWithCurrManager
# 0                     17.891156
# 1                      5.170068
# 2                     23.401361
# 3                      9.659864
# 4                      6.666667
# 5                      2.108844
# 6                      1.972789
# 7                     14.693878
# 8                      7.278912
# 9                      4.353741
# 10                     1.836735
# 11                     1.496599
# 12                     1.224490
# 13                     0.952381
# 14                     0.340136
# 15                     0.340136
# 16                     0.136054
# 17                     0.476190

# %% [markdown]
# ## Visualization of YearsWithCurrManager

# %%
atr.hist(column = 'YearsWithCurrManager')
plt.show()

# %% [markdown]
# ## Distance from home

# %%
univ=pd.crosstab(atr.DistanceFromHome,columns="frequency")/n*100
univ
# Out:
# col_0             frequency
# DistanceFromHome
# 1                 14.149660
# 2                 14.353741
# 3                  5.714286
# 4                  4.353741
# 5                  4.421769
# 6                  4.013605
# 7                  5.714286
# 8                  5.442177
# 9                  5.782313
# 10                 5.850340
# 11                 1.972789
# 12                 1.360544
# 13                 1.292517
# 14                 1.428571
# 15                 1.768707
# 16                 2.176871
# 17                 1.360544
# 18                 1.768707
# 19                 1.496599
# 20                 1.700680
# 21                 1.224490
# 22                 1.292517
# 23                 1.836735
# 24                 1.904762
# 25                 1.700680
# 26                 1.700680
# 27                 0.816327
# 28                 1.564626
# 29                 1.836735

# %% [markdown]
# ## Visualization of Distance from home

# %%
atr.hist(column = 'DistanceFromHome')
plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# ## AGE

# %%
bivar=pd.crosstab(atr.Age,columns=atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition           0          1
# Age
# 18          50.000000  50.000000
# 19          33.333333  66.666667
# 20          45.454545  54.545455
# 21          53.846154  46.153846
# 22          68.750000  31.250000
# 23          71.428571  28.571429
# 24          73.076923  26.923077
# 25          76.923077  23.076923
# 26          69.230769  30.769231
# 27          93.750000   6.250000
# 28          70.833333  29.166667
# 29          73.529412  26.470588
# 30          85.000000  15.000000
# 31          73.913043  26.086957
# 32          81.967213  18.032787
# 33          79.310345  20.689655
# 34          88.311688  11.688312
# 35          87.179487  12.820513
# 36          91.304348   8.695652
# 37          88.000000  12.000000
# 38          96.551724   3.448276
# 39          85.714286  14.285714
# 40          91.228070   8.771930
# 41          85.000000  15.000000
# 42          95.652174   4.347826
# 43          93.750000   6.250000
# 44          81.818182  18.181818
# ...

# %% [markdown]
# ## Visualisation of Age with Attrition

# %%
atr.boxplot(column = 'Age',
              by = 'Attrition',
              vert = False,
              figsize = (7,5) , 
              rot = 45)

plt.show()

# %%
# under our analysis,we can conclude that the distribution of the employees in both box plots  are more or less similar
# hence it show that it does not affect the attrition effectively

# %% [markdown]
# ## BusinessTravel

# %%
bivar=pd.crosstab(atr.EnvironmentSatisfaction,columns=atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                        0          1
# EnvironmentSatisfaction
# 1                        74.647887  25.352113
# 2                        85.017422  14.982578
# 3                        86.313466  13.686534
# 4                        86.547085  13.452915

# %%
#Bivariate Analysis with Attrition

#Percentage of attrition across categories
tab = pd.crosstab(atr.BusinessTravel,atr.Attrition,normalize='index')*100
print(tab)
tab.plot(kind='bar',figsize=(6,4))
plt.xticks(rotation = 0)
plt.show()
plt.savefig('qw.jpg')
# Out:
# Attrition                  0          1
# BusinessTravel
# Non-Travel         92.000000   8.000000
# Travel_Frequently  75.090253  24.909747
# Travel_Rarely      85.043145  14.956855

# %% [markdown]
# ## Department

# %%
bivar=pd.crosstab(atr.Department,atr.Attrition,normalize="index")*100
bivar   #doubt for conclusion
# Out:
# Attrition                       0          1
# Department
# Human Resources         80.952381  19.047619
# Research & Development  86.160250  13.839750
# Sales                   79.372197  20.627803

# %%
#Bivariate Analysis with Attrition

#Percentage of attrition across categories
tab = pd.crosstab(atr.Department,atr.Attrition,normalize='index')*100
print(tab)
tab.plot(kind='bar')
plt.show()
# Out:
# Attrition                       0          1
# Department
# Human Resources         80.952381  19.047619
# Research & Development  86.160250  13.839750
# Sales                   79.372197  20.627803

# %% [markdown]
# ## EducationField

# %%
bivar=pd.crosstab(atr.EducationField,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                 0          1
# EducationField
# Human Resources   74.074074  25.925926
# Life Sciences     85.313531  14.686469
# Marketing         77.987421  22.012579
# Medical           86.422414  13.577586
# Other             86.585366  13.414634
# Technical Degree  75.757576  24.242424

# %%
#Bivariate Analysis with Attrition

#Percentage of attrition across categories
tab = pd.crosstab(attrition.EducationField,attrition.Attrition,normalize='index')*100
print(tab)
tab.plot(kind='bar')
plt.show()

# %% [markdown]
# ## EnvironmentSatisfaction

# %%
bivar=pd.crosstab(atr.EnvironmentSatisfaction,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                        0          1
# EnvironmentSatisfaction
# 1                        74.647887  25.352113
# 2                        85.017422  14.982578
# 3                        86.313466  13.686534
# 4                        86.547085  13.452915

# %%
#Bivariate Analysis with Attrition

#Percentage of attrition across categories
tab = pd.crosstab(atr.EnvironmentSatisfaction,atr.Attrition,normalize='index')*100
print(tab)
tab.plot(kind='bar',figsize=(7,6))
plt.xticks(rotation = 0)
plt.show()
# Out:
# Attrition                        0          1
# EnvironmentSatisfaction
# 1                        74.647887  25.352113
# 2                        85.017422  14.982578
# 3                        86.313466  13.686534
# 4                        86.547085  13.452915

# %% [markdown]
# ## Gender

# %%
bivar=pd.crosstab(atr.Gender,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition          0          1
# Gender
# Female     85.204082  14.795918
# Male       82.993197  17.006803

# %%
#Bivariate Analysis with Attrition

#Percentage of attrition across categories
tab = pd.crosstab(atr.Gender,atr.Attrition,normalize='index')*100
print(tab)
tab.plot(kind='bar')
plt.show()
# Out:
# Attrition          0          1
# Gender
# Female     85.204082  14.795918
# Male       82.993197  17.006803

# %% [markdown]
# ## JobInvolvement

# %%
bivar=pd.crosstab(atr.JobInvolvement,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition               0          1
# JobInvolvement
# 1               66.265060  33.734940
# 2               81.066667  18.933333
# 3               85.599078  14.400922
# 4               90.972222   9.027778

# %%
bivar=pd.crosstab(atr.JobInvolvement,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='JobInvolvement',y=1)
plt.show()

# %% [markdown]
# ## JobLevel (check graph)

# %%
bivar=pd.crosstab(atr.JobLevel,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition          0          1
# JobLevel
# 1          73.664825  26.335175
# 2          90.262172   9.737828
# 3          85.321101  14.678899
# 4          95.283019   4.716981
# 5          92.753623   7.246377

# %%
bivar=pd.crosstab(atr.JobLevel,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='JobLevel',y=1)
plt.show()

# %% [markdown]
# ## JobSatisfaction

# %%
bivar=pd.crosstab(atr.JobSatisfaction,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                0          1
# JobSatisfaction
# 1                77.162630  22.837370
# 2                83.571429  16.428571
# 3                83.484163  16.515837
# 4                88.671024  11.328976

# %%
bivar=pd.crosstab(atr.JobSatisfaction,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='JobSatisfaction',y=1)
plt.show()

# %% [markdown]
# ## MaritalStatus

# %%
bivar=pd.crosstab(atr.MaritalStatus,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition              0          1
# MaritalStatus
# Divorced       89.908257  10.091743
# Married        87.518574  12.481426
# Single         74.468085  25.531915

# %%
#Bivariate Analysis with Attrition

#Percentage of attrition across categories
tab = pd.crosstab(atr.MaritalStatus,atr.Attrition,normalize='index')*100
print(tab)
tab.plot(kind='bar',figsize=(6,5))
plt.xticks(rotation = 0)
plt.show()


#under our analysis,in this company,employees who are  in the category of single having higher possibility to leave the company,
#comparing divorced and married .
#interpretation:
 # This may be due to lack of committments and responsibilities.
# Out:
# Attrition              0          1
# MaritalStatus
# Divorced       89.908257  10.091743
# Married        87.518574  12.481426
# Single         74.468085  25.531915

# %% [markdown]
# ## MonthlyIncome

# %%
bivar=pd.crosstab(atr.MonthlyIncome,atr.Attrition,normalize="index")*100

pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',2000)

bivar
# Out:
# Attrition               0           1
# MonthlyIncome
# 1009             0.000000  100.000000
# 1051           100.000000    0.000000
# 1052           100.000000    0.000000
# 1081             0.000000  100.000000
# 1091             0.000000  100.000000
# 1102             0.000000  100.000000
# 1118             0.000000  100.000000
# 1129           100.000000    0.000000
# 1200           100.000000    0.000000
# 1223           100.000000    0.000000
# 1232           100.000000    0.000000
# 1261             0.000000  100.000000
# 1274           100.000000    0.000000
# 1281           100.000000    0.000000
# 1359             0.000000  100.000000
# 1393             0.000000  100.000000
# 1416             0.000000  100.000000
# 1420             0.000000  100.000000
# 1483           100.000000    0.000000
# 1514           100.000000    0.000000
# 1555             0.000000  100.000000
# 1563           100.000000    0.000000
# 1569             0.000000  100.000000
# ...

# %%
atr.boxplot(column = 'MonthlyIncome',
              by = 'Attrition',
              vert = False,
              figsize = (7,5) , 
              rot = 45)

plt.show()

# %% [markdown]
# ## OverTime

# %%
bivar=pd.crosstab(atr.OverTime,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition          0          1
# OverTime
# No         89.563567  10.436433
# Yes        69.471154  30.528846

# %%
#Bivariate Analysis with Attrition

#Percentage of attrition across categories
tab = pd.crosstab(atr.OverTime,atr.Attrition,normalize='index')*100
print(tab)
tab.plot(kind='bar',figsize=(6,5))
plt.xticks(rotation=0)
plt.show()
# Out:
# Attrition          0          1
# OverTime
# No         89.563567  10.436433
# Yes        69.471154  30.528846

# %% [markdown]
# ## TotalWorkingYears

# %%
bivar=pd.crosstab(atr.TotalWorkingYears,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                   0           1
# TotalWorkingYears
# 0                   54.545455   45.454545
# 1                   50.617284   49.382716
# 2                   70.967742   29.032258
# 3                   78.571429   21.428571
# 4                   80.952381   19.047619
# 5                   81.818182   18.181818
# 6                   82.400000   17.600000
# 7                   77.777778   22.222222
# 8                   84.466019   15.533981
# 9                   89.583333   10.416667
# 10                  87.623762   12.376238
# 11                  80.555556   19.444444
# 12                  89.583333   10.416667
# 13                  91.666667    8.333333
# 14                  87.096774   12.903226
# 15                  87.500000   12.500000
# 16                  91.891892    8.108108
# 17                  90.909091    9.090909
# 18                  85.185185   14.814815
# 19                  86.363636   13.636364
# 20                  93.333333    6.666667
# ...

# %%
bivar=pd.crosstab(atr.TotalWorkingYears,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='TotalWorkingYears',y=1)
plt.show()

# %% [markdown]
# ## WorkLifeBalance

# %%
bivar=pd.crosstab(atr.WorkLifeBalance,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                0          1
# WorkLifeBalance
# 1                68.750000  31.250000
# 2                83.139535  16.860465
# 3                85.778275  14.221725
# 4                82.352941  17.647059

# %%
#Bivariate Analysis with Attrition

#Percentage of attrition across categories
tab = pd.crosstab(atr.WorkLifeBalance,atr.Attrition,normalize='index')*100
print(tab)
tab.plot(kind='bar',figsize=(6,5))
plt.xticks(rotation=0)
plt.show()
# Out:
# Attrition                0          1
# WorkLifeBalance
# 1                68.750000  31.250000
# 2                83.139535  16.860465
# 3                85.778275  14.221725
# 4                82.352941  17.647059

# %% [markdown]
# ##  YearsAtCompany

# %%
bivar=pd.crosstab(atr.YearsAtCompany,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                0           1
# YearsAtCompany
# 0                63.636364   36.363636
# 1                65.497076   34.502924
# 2                78.740157   21.259843
# 3                84.375000   15.625000
# 4                82.727273   17.272727
# 5                89.285714   10.714286
# 6                88.157895   11.842105
# 7                87.777778   12.222222
# 8                88.750000   11.250000
# 9                90.243902    9.756098
# 10               85.000000   15.000000
# 11               93.750000    6.250000
# 12              100.000000    0.000000
# 13               91.666667    8.333333
# 14               88.888889   11.111111
# 15               95.000000    5.000000
# 16               91.666667    8.333333
# 17               88.888889   11.111111
# 18               92.307692    7.692308
# 19               90.909091    9.090909
# 20               96.296296    3.703704
# 21               92.857143    7.142857
# ...

# %%
bivar=pd.crosstab(atr.YearsAtCompany,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='YearsAtCompany',y=1)
plt.show()

# %% [markdown]
# ## YearsInCurrentRole

# %%
bivar=pd.crosstab(atr.YearsInCurrentRole,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                    0          1
# YearsInCurrentRole
# 0                    70.081967  29.918033
# 1                    80.701754  19.298246
# 2                    81.720430  18.279570
# 3                    88.148148  11.851852
# 4                    85.576923  14.423077
# 5                    97.222222   2.777778
# 6                    94.594595   5.405405
# 7                    86.036036  13.963964
# 8                    92.134831   7.865169
# 9                    91.044776   8.955224
# 10                   93.103448   6.896552
# 11                  100.000000   0.000000
# 12                   90.000000  10.000000
# 13                   92.857143   7.142857
# 14                   90.909091   9.090909
# 15                   75.000000  25.000000
# 16                  100.000000   0.000000
# 17                  100.000000   0.000000
# 18                  100.000000   0.000000

# %%
bivar=pd.crosstab(atr.YearsInCurrentRole,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='YearsInCurrentRole',y=1)
plt.show()

# %% [markdown]
# ## YearsSinceLastPromotion

# %%
bivar=pd.crosstab(atr.YearsSinceLastPromotion,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                         0          1
# YearsSinceLastPromotion
# 0                         81.067126  18.932874
# 1                         86.274510  13.725490
# 2                         83.018868  16.981132
# 3                         82.692308  17.307692
# 4                         91.803279   8.196721
# 5                         95.555556   4.444444
# 6                         81.250000  18.750000
# 7                         78.947368  21.052632
# 8                        100.000000   0.000000
# 9                         76.470588  23.529412
# 10                        83.333333  16.666667
# 11                        91.666667   8.333333
# 12                       100.000000   0.000000
# 13                        80.000000  20.000000
# 14                        88.888889  11.111111
# 15                        76.923077  23.076923

# %%
bivar=pd.crosstab(atr.YearsSinceLastPromotion,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='YearsSinceLastPromotion',y=1)
plt.show()

# %% [markdown]
# ## YearsWithCurrManager

# %%
bivar=pd.crosstab(atr.YearsWithCurrManager,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                      0          1
# YearsWithCurrManager
# 0                      67.680608  32.319392
# 1                      85.526316  14.473684
# 2                      85.465116  14.534884
# 3                      86.619718  13.380282
# 4                      88.775510  11.224490
# 5                      87.096774  12.903226
# 6                      86.206897  13.793103
# 7                      85.648148  14.351852
# 8                      90.654206   9.345794
# 9                      90.625000   9.375000
# 10                     88.888889  11.111111
# 11                     95.454545   4.545455
# 12                    100.000000   0.000000
# 13                    100.000000   0.000000
# 14                     60.000000  40.000000
# 15                    100.000000   0.000000
# 16                    100.000000   0.000000
# 17                    100.000000   0.000000

# %%
bivar=pd.crosstab(atr.YearsWithCurrManager,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='YearsWithCurrManager',y=1)
plt.show()

# %% [markdown]
# ## DistanceFromHome

# %%
bivar=pd.crosstab(atr.DistanceFromHome,atr.Attrition,normalize="index")*100
bivar
# Out:
# Attrition                 0          1
# DistanceFromHome
# 1                 87.500000  12.500000
# 2                 86.729858  13.270142
# 3                 83.333333  16.666667
# 4                 85.937500  14.062500
# 5                 84.615385  15.384615
# 6                 88.135593  11.864407
# 7                 86.904762  13.095238
# 8                 87.500000  12.500000
# 9                 78.823529  21.176471
# 10                87.209302  12.790698
# 11                86.206897  13.793103
# 12                70.000000  30.000000
# 13                68.421053  31.578947
# 14                80.952381  19.047619
# 15                80.769231  19.230769
# 16                78.125000  21.875000
# 17                75.000000  25.000000
# 18                84.615385  15.384615
# 19                86.363636  13.636364
# 20                84.000000  16.000000
# 21                83.333333  16.666667
# 22                68.421053  31.578947
# ...

# %%
bivar=pd.crosstab(atr.DistanceFromHome,atr.Attrition,normalize="index")*100
bivar.reset_index(inplace=True)
bivar
bivar.plot(x='DistanceFromHome',y=1)
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
multivar=pd.crosstab([atr.JobSatisfaction,atr.OverTime],columns=atr.Attrition,normalize="index")*100
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar
# Out:
# Attrition                         0          1
# JobSatisfaction OverTime
# 1               No        82.439024  17.560976
#                 Yes       64.285714  35.714286
# 2               No        90.521327   9.478673
#                 Yes       62.318841  37.681159
# 3               No        90.031153   9.968847
#                 Yes       66.115702  33.884298
# 4               No        93.059937   6.940063
#                 Yes       78.873239  21.126761

# %%
multivar=pd.crosstab([atr.JobSatisfaction,atr.OverTime],columns=atr.Attrition)
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar
# Out:
# Attrition                   0   1
# JobSatisfaction OverTime
# 1               No        169  36
#                 Yes        54  30
# 2               No        191  20
#                 Yes        43  26
# 3               No        289  32
#                 Yes        80  41
# 4               No        295  22
#                 Yes       112  30

# %%
multivar=pd.crosstab([atr.JobInvolvement,atr.MaritalStatus],columns=atr.Attrition,normalize="index")*100

pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar
# Out:
# Attrition                             0          1
# JobInvolvement MaritalStatus
# 1              Divorced       81.818182  18.181818
#                Married        69.696970  30.303030
#                Single         50.000000  50.000000
# 2              Divorced       85.915493  14.084507
#                Married        87.428571  12.571429
#                Single         69.767442  30.232558
# 3              Divorced       91.000000   9.000000
#                Married        87.468031  12.531969
#                Single         79.061372  20.938628
# 4              Divorced       97.058824   2.941176
#                Married        95.945946   4.054054
#                Single         75.000000  25.000000

# %%
multivar=pd.crosstab([atr.JobInvolvement,atr.MaritalStatus],columns=atr.Attrition)

pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar
# Out:
# Attrition                       0   1
# JobInvolvement MaritalStatus
# 1              Divorced        18   4
#                Married         23  10
#                Single          14  14
# 2              Divorced        61  10
#                Married        153  22
#                Single          90  39
# 3              Divorced       182  18
#                Married        342  49
#                Single         219  58
# 4              Divorced        33   1
#                Married         71   3
#                Single          27   9

# %%
multivar=pd.crosstab([atr.OverTime,atr.WorkLifeBalance],columns=atr.Attrition,normalize="index")*100

pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar
# Out:
# Attrition                         0          1
# OverTime WorkLifeBalance
# No       1                74.137931  25.862069
#          2                89.166667  10.833333
#          3                91.549296   8.450704
#          4                87.179487  12.820513
# Yes      1                54.545455  45.454545
#          2                69.230769  30.769231
#          3                71.259843  28.740157
#          4                66.666667  33.333333

# %%
multivar=pd.crosstab([atr.OverTime,atr.WorkLifeBalance],columns=atr.Attrition)

pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar
# Out:
# Attrition                   0   1
# OverTime WorkLifeBalance
# No       1                 43  15
#          2                214  26
#          3                585  54
#          4                102  15
# Yes      1                 12  10
#          2                 72  32
#          3                181  73
#          4                 24  12

# %% [markdown]
# ## multivariate using overtime,maritalstatus,worklifebalance

# %%
multivar=pd.crosstab([atr.OverTime,atr.MaritalStatus,atr.WorkLifeBalance],columns=atr.Attrition,normalize="index")*100
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar
# Out:
# Attrition                                        0          1
# OverTime MaritalStatus WorkLifeBalance
# No       Divorced      1                 77.777778  22.222222
#                        2                 91.803279   8.196721
#                        3                 95.488722   4.511278
#                        4                 96.000000   4.000000
#          Married       1                 80.645161  19.354839
#                        2                 93.203883   6.796117
#                        3                 93.243243   6.756757
#                        4                 85.964912  14.035088
#          Single        1                 61.111111  38.888889
#                        2                 81.578947  18.421053
#                        3                 86.666667  13.333333
#                        4                 82.857143  17.142857
# Yes      Divorced      1                 50.000000  50.000000
# ...

# %%
multivar= pd.crosstab([atr.Department,atr.EducationField,atr.JobInvolvement],columns=atr.Attrition,normalize="index")*100
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar      
# under our analysis, attrition rate is only 20% for employee who are working in the same domain 
              #with higher level of job involvement.
              #under our analysis,attrition rate is 50% for employee who are working in the same domain but 
        #lack of job involvement.
# Out:
# Attrition                                                        0           1
# Department             EducationField   JobInvolvement
# Human Resources        Human Resources  1                50.000000   50.000000
#                                         2                62.500000   37.500000
#                                         3                83.333333   16.666667
#                                         4                80.000000   20.000000
#                        Life Sciences    1               100.000000    0.000000
#                                         2               100.000000    0.000000
#                                         3                90.909091    9.090909
#                        Medical          2                66.666667   33.333333
#                                         3                87.500000   12.500000
#                                         4               100.000000    0.000000
# ...

# %%
multivar=pd.crosstab([atr.Department,atr.EducationField,atr.JobInvolvement],columns=atr.Attrition)
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar
# Out:
# Attrition                                                 0   1
# Department             EducationField   JobInvolvement
# Human Resources        Human Resources  1                 1   1
#                                         2                 5   3
#                                         3                10   2
#                                         4                 4   1
#                        Life Sciences    1                 1   0
#                                         2                 4   0
#                                         3                10   1
#                        Medical          2                 2   1
#                                         3                 7   1
#                                         4                 2   0
#                        Other            2                 1   0
#                                         3                 2   0
#                        Technical Degree 2                 0   1
# ...

# %%
multivar=pd.crosstab([atr.EducationField,atr.Gender],columns=atr.Attrition,normalize="index")*100
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar #
# Out:
# Attrition                        0          1
# EducationField   Gender
# Human Resources  Female  62.500000  37.500000
#                  Male    78.947368  21.052632
# Life Sciences    Female  84.166667  15.833333
#                  Male    86.065574  13.934426
# Marketing        Female  78.260870  21.739130
#                  Male    77.777778  22.222222
# Medical          Female  90.000000  10.000000
#                  Male    83.941606  16.058394
# Other            Female  93.103448   6.896552
#                  Male    83.018868  16.981132
# Technical Degree Female  80.769231  19.230769
#                  Male    72.500000  27.500000

# %%
multivar=pd.crosstab([atr.Age,atr.YearsWithCurrManager],columns=atr.Attrition,normalize="index")*100
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',500)
multivar   #under our analysis,all employee who are in the age group of 60 are loyal to the company 
           #irrespective of years working with current manager.
           #its also concluded that they are going to be retired soon ,so there is need to change the company at this age.
# Out:
# Attrition                          0           1
# Age YearsWithCurrManager
# 18  0                      50.000000   50.000000
# 19  0                      25.000000   75.000000
#     1                     100.000000    0.000000
# 20  0                      25.000000   75.000000
#     1                       0.000000  100.000000
#     2                      66.666667   33.333333
# 21  0                      33.333333   66.666667
#     2                      71.428571   28.571429
# 22  0                      40.000000   60.000000
#     1                     100.000000    0.000000
#     2                      75.000000   25.000000
#     3                     100.000000    0.000000
# 23  0                      33.333333   66.666667
#     1                     100.000000    0.000000
#     2                      77.777778   22.222222
#     4                     100.000000    0.000000
# 24  0                      44.444444   55.555556
#     1                     100.000000    0.000000
# ...
